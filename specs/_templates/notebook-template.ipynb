# %% [markdown]
# # Kata NN — <Título>
#
# > Spec: [`specs/NNN-slug/spec.md`](../../specs/NNN-slug/spec.md)  |  Arquitectura: [`ARCHITECTURE.md`](../../ARCHITECTURE.md)
#
# **Cero mocks.** Este notebook llama a la API real de Anthropic. Las seis secciones siguientes son obligatorias (Constitución, Principio VIII).

# %% [markdown]
# ## Setup
#
# Si `ANTHROPIC_API_KEY` no está en el entorno, se pedirá aquí (sin echo).

# %%
from katas._shared.bootstrap import bootstrap

client, settings = bootstrap()  # añade model=, max_tokens=, budget_calls= si quieres override
print("modelo:", settings.model, "| presupuesto:", settings.budget_calls, "llamadas")

# %% [markdown]
# ## 1. Concepto en mis palabras
#
# Reformula la idea del spec en 2-4 líneas propias.

# %% [markdown]
# ## 2. Por qué importa
#
# Nombra la falla concreta que este kata previene.

# %% [markdown]
# ## 3. Ejemplo correcto
#
# Llamadas reales al modelo. El código demuestra el patrón **bien hecho**.

# %%
# TODO: implementación correcta usando `client.messages.create(...)`

# %% [markdown]
# ## 4. Anti-patrón (lado a lado)
#
# Misma llamada / misma tarea, hecha mal a propósito. La API es la misma.

# %%
# TODO: reproducir el error y mostrar el síntoma del fallo

# %% [markdown]
# ## 5. Argumento de certificación
#
# - …
# - …
# - …

# %% [markdown]
# ## 6. Auto-evaluación
#
# Responde aquí las preguntas de la sección "Auto-evaluación" del `spec.md`.
#
# 1. **Q:** …
#    **A:** …
# 2. **Q:** …
#    **A:** …
# 3. **Q:** …
#    **A:** …
